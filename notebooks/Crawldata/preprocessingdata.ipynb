# %% [markdown]
# ## test

# %%
import re

# Câu văn ban đầu
text = """  Bô ̣ Quy tắc ứng xử
của người học (go ̣ i tắt là “Quy tắc này”) đươ ̣ c ban h ành nhằm tạo lập
môi trường học tập, nghiên cứu bình đẳng, công bằng, văn minh và hiệu quả. Người
học được tôn trọng, có quyền tự do ứng xử theo nguyên tắc tuyê ̣ t đối tuân
thủ pháp luật, tôn tro ̣ ng quyền và lợi ích hợp pháp của Nhà nước, Nhà
trường và của các tổ chức, cá nhân khác.  Quy tắc này bao gồm những nguyên
tắc cơ bản trong ứng xử của người học trong phạm vi Trường Đa ̣ i ho ̣ c Tôn Đ
ức Thắng (go ̣ i t ắt là “Trường” hoă ̣ c “Nhà trường”) và trong một số
quan hệ xã hội khác mà Quy tắc này điều chỉnh.  Quy tắc này và Quy chế Công tác
sinh viên, Quy chế quản lý người học trình độ thạc sĩ, tiến sĩ là cơ sở pháp lý
để người học có thể thực hiện quyền cơ bản và chịu các trách nhiệm trong học
tập, ứng xử tại Trường và trong các quan hệ xã hội.  Trong trường hợp người học
có những hành vi ứng xử đáng khen, Nhà trường áp dụng các quy định về khen
thưởng để tuyên dương và tặng thưởng.  Trong trường hợp người học có hành vi
ứng xử vi pha ̣ mpháp luâ ̣ t ho ă ̣ c/và vi pha ̣ m Quy tắc này, Nhà trường
áp dụng Quy chế Công tác sinh viên (đối với người học trình độ đại học) hoặc Quy
chế quản lý người học trình độ thạc sĩ, tiến sĩ (đối với người học trình độ thạc
sĩ, tiến sĩ) để xử lý.
a) Cộng đồng người học Trường Đại học Tôn Đức Thắng đươ ̣ c xem l
à văn minh, hiện đại và có chuẩn mực khi thỏa mã n c ác điều kiê ̣ n: (1)
mọi người được đối xử bình đẳng về dân tộc, tôn giáo, giới tính, ngôn ngữ; (2)
từng người được tôn trọng những khác biệt trên cơ sở quy định của pháp luật và
nội quy, quy chế của Nhà trường; (3) người học tôn trọng sự công bằng trong học
tập, thi cử, nghiên cứu khoa học và cơ hội làm việc. b) Người học được đảm bảo:
(1) đối xử bình đẳng trong học tập, nghiên cứu khoa học và các hoạt động khác
tại Trường; (2) được tôn trọng các thông tin cá nhân và được bảo mật các thông
tin cá nhân theo quy đi ̣ nh c ủa pháp luâ ̣ t; (3) được quyền khiếu nại về
các vấn đề liên quan đến quyền, nghĩa vụ hợp pháp trong quátrì nh h o ̣ c t â
̣ p, nghiên c ứu ta ̣ i Trư ờng; (4) được giải quyết các khiếu na ̣ i nhanh
chóng, công bằng và đúng pháp luật, đúng quy chế, quy đi ̣ nh c ủa Trường. """

# Bước 1: Loại bỏ khoảng trắng không cần thiết trước các dấu thanh và xung quanh các chữ cái đơn lẻ
# Xóa khoảng trắng giữa từ và dấu thanh
text = re.sub(r'(\w)\s+([̣̀́̉̃])', r'\1\2', text)  
# Xóa khoảng trắng giữa dấu thanh và từ tiếp theo nếu có
text = re.sub(r'([̣̀́̉̃])\s+(\w)', r'\1\2', text)  

# Bước 2: Thêm khoảng trắng giữa các từ viết hoa liền nhau (như "Bộ" và "Quy")
# Chỉ thêm khoảng trắng giữa các từ có ký tự viết hoa liền nhau
text = re.sub(r'(?<=[a-zA-ZÀ-ỹ])(?=[A-Z])', ' ', text)

# Bước 3: Xóa khoảng trắng không cần thiết trong các từ có dấu tiếng Việt
# Xóa khoảng trắng giữa các chữ cái và dấu thanh nếu còn tồn tại
text = re.sub(r'(\w)\s+([̣̀́̉̃]\w)', r'\1\2', text)
text = re.sub(r'\b(\w)\s(\w)\b', r'\1\2', text)  # Áp dụng cho các trường hợp khác
# Bước 4: Chuẩn hóa một số lỗi mã hóa phổ biến trong tiếng Việt (nếu cần)
def normalize_vietnamese_text(text):
    replacements = {
        "à": "à", "á": "á", "ả": "ả", "ã": "ã", "ạ": "ạ",
        "ầ": "ầ", "ấ": "ấ", "ẩ": "ẩ", "ẫ": "ẫ", "ậ": "ậ",
        "ằ": "ằ", "ắ": "ắ", "ẳ": "ẳ", "ẵ": "ẵ", "ặ": "ặ",
        "è": "è", "é": "é", "ẻ": "ẻ", "ẽ": "ẽ", "ẹ": "ẹ",
        "ò": "ò", "ó": "ó", "ỏ": "ỏ", "õ": "õ", "ọ": "ọ",
        "ồ": "ồ", "ố": "ố", "ổ": "ổ", "ỗ": "ỗ", "ộ": "ộ",
        "ờ": "ờ", "ớ": "ớ", "ở": "ở", "ỡ": "ỡ", "ợ": "ợ",
        "ù": "ù", "ú": "ú", "ủ": "ủ", "ũ": "ũ", "ụ": "ụ",
        "ừ": "ừ", "ứ": "ứ", "ử": "ử", "ữ": "ữ", "ự": "ự",
        "ì": "ì", "í": "í", "ỉ": "ỉ", "ĩ": "ĩ", "ị": "ị",
        "ỳ": "ỳ", "ý": "ý", "ỷ": "ỷ", "ỹ": "ỹ", "ỵ": "ỵ"
    }
    for wrong, correct in replacements.items():
        text = text.replace(wrong, correct)
    return text

text = normalize_vietnamese_text(text)

# Bước 5: Gộp các dòng văn bản thành một câu hoàn chỉnh
text = text.replace('\n', ' ')

# Xóa khoảng trắng thừa nếu có
text = re.sub(r'\s+', ' ', text).strip()

# In kết quả
print(text)
# Out:
# Bộ Quy tắc ứng xử của người học (gọi tắt là “Quy tắc này”) được ban hành nhằm tạo lập môi trường học tập, nghiên cứu bình đẳng, công bằng, văn minh và hiệu quả. Người học được tôn trọng, có quyền tự do ứng xử theo nguyên tắc tuyệt đối tuân thủpháp luật, tôn trọng quyền và lợi ích hợp pháp của Nhànước, Nhà trường và của các tổchức, cá nhân khác. Quy tắc này bao gồm những nguyên tắc cơ bản trong ứng xử của người học trong phạm vi Trường Đại học Tôn Đức Thắng (gọit ắt là “Trường” hoặc “Nhà trường”) và trong một số quan hệ xã hội khác mà Quy tắc này điều chỉnh. Quy tắc này và Quy chế Công tác sinh viên, Quy chế quản lý người học trình độ thạc sĩ, tiến sĩ là cơ sở pháp lý để người học có thể thực hiện quyền cơ bản và chịu các trách nhiệm trong học tập, ứng xử tại Trường và trong các quan hệ xã hội. Trong trường hợp người học có những hành vi ứng xử đáng khen, Nhà trường áp dụng các quy định về khen thưởng để tuyên dương và tặng thưởng. Trong trường hợp người học có hành vi ứng xử vi phạm
# ...

# %% [markdown]
# # Cleaning

# %%
import re
from textwrap import fill

def format_text(input_text):
    """
    Định dạng văn bản với các điều kiện:
    - Tiêu đề lớn: "BỘ QUY TẮC ỨNG XỬ CỦA NGƯỜI HỌC" được giữ nguyên định dạng.
    - Các mục lớn: "I.", "II.", ...
    - Các mục nhỏ: "1.", "2.", ...
    - Các mục con: "a)", "b)", ...
    """
    # Loại bỏ khoảng trắng thừa và gộp các dòng bị ngắt
    cleaned_text = re.sub(r'\n+', ' ', input_text)
    cleaned_text = re.sub(r'\s{2,}', ' ', cleaned_text)

    # Format tiêu đề chính: "BỘ QUY TẮC ỨNG XỬ CỦA NGƯỜI HỌC"
    cleaned_text = re.sub(r'(BỘ QUY TẮC ỨNG XỬ CỦA NGƯỜI HỌC)', r'\n\1\n', cleaned_text)

    # Format các mục lớn: "I.", "II.", ...
    cleaned_text = re.sub(r'([IVXLCDM]+\.)', r'\n\n\1', cleaned_text)

    # Format các mục nhỏ: "1.", "2.", ...
    cleaned_text = re.sub(r'(\d+\.)', r'\n\1', cleaned_text)

    # Format các mục con: "a)", "b)", ...
    cleaned_text = re.sub(r'([a-z]\))', r'\n\1', cleaned_text)

    # Gói nội dung dài thành các dòng tối đa 80 ký tự
    lines = cleaned_text.splitlines()
    wrapped_lines = [fill(line.strip(), width=80) if line.strip() else line for line in lines]

    # Kết hợp lại thành văn bản hoàn chỉnh
    return "\n".join(wrapped_lines).strip()

# Ví dụ văn bản đầu vào
input_text = """
Page 1:

 BỘ QUY TẮC ỨNG XỬ CỦA NGƯỜI HỌC I. MỤC TIÊU VÀ NGUYÊN TẮC:  Bô ̣ Quy tắc ứng xử
của người học (go ̣ i tắt là “Quy tắc này”) đươ ̣ c ban h ành nhằm tạo lập
môi trường học tập, nghiên cứu bình đẳng, công bằng, văn minh và hiệu quả. Người
học được tôn trọng, có quyền tự do ứng xử theo nguyên tắc tuyê ̣ t đối tuân
thủ pháp luật, tôn tro ̣ ng quyền và lợi ích hợp pháp của Nhà nước, Nhà
trường và của các tổ chức, cá nhân khác.  Quy tắc này bao gồm những nguyên
tắc cơ bản trong ứng xử của người học trong phạm vi Trường Đa ̣ i ho ̣ c Tôn Đ
ức Thắng (go ̣ i t ắt là “Trường” hoă ̣ c “Nhà trường”) và trong một số
quan hệ xã hội khác mà Quy tắc này điều chỉnh.  Quy tắc này và Quy chế Công tác
sinh viên, Quy chế quản lý người học trình độ thạc sĩ, tiến sĩ là cơ sở pháp lý
để người học có thể thực hiện quyền cơ bản và chịu các trách nhiệm trong học
tập, ứng xử tại Trường và trong các quan hệ xã hội.  Trong trường hợp người học
có những hành vi ứng xử đáng khen, Nhà trường áp dụng các quy định về khen
thưởng để tuyên dương và tặng thưởng.  Trong trường hợp người học có hành vi
ứng xử vi pha ̣ mpháp luâ ̣ t ho ă ̣ c/và vi pha ̣ m Quy tắc này, Nhà trường
áp dụng Quy chế Công tác sinh viên (đối với người học trình độ đại học) hoặc Quy
chế quản lý người học trình độ thạc sĩ, tiến sĩ (đối với người học trình độ thạc
sĩ, tiến sĩ) để xử lý. II. NỘI DUNG CỦA QUY TẮC:  TẠO LẬP MÔI TRƯỜNG VĂN MINH VÀ
CÓ CHUẨN MỰC: a) Cộng đồng người học Trường Đại học Tôn Đức Thắng đươ ̣ c xem l
à văn minh, hiện đại và có chuẩn mực khi thỏa mã n c ác điều kiê ̣ n: (1)
mọi người được đối xử bình đẳng về dân tộc, tôn giáo, giới tính, ngôn ngữ; (2)
từng người được tôn trọng những khác biệt trên cơ sở quy định của pháp luật và
nội quy, quy chế của Nhà trường; (3) người học tôn trọng sự công bằng trong học
tập, thi cử, nghiên cứu khoa học và cơ hội làm việc. b) Người học được đảm bảo:
(1) đối xử bình đẳng trong học tập, nghiên cứu khoa học và các hoạt động khác
tại Trường; (2) được tôn trọng các thông tin cá nhân và được bảo mật các thông
tin cá nhân theo quy đi ̣ nh c ủa pháp luâ ̣ t; (3) được quyền khiếu nại về
các vấn đề liên quan đến quyền, nghĩa vụ hợp pháp trong quátrì nh h o ̣ c t â
̣ p, nghiên c ứu ta ̣ i Trư ờng; (4) được giải quyết các khiếu na ̣ i nhanh
chóng, công bằng và đúng pháp luật, đúng quy chế, quy đi ̣ nh c ủa Trường.

"""

# Chạy hàm định dạng
formatted_text = format_text(input_text)

# In ra kết quả
print(formatted_text)
# Out:
# Page 1:
# BỘ QUY TẮC ỨNG XỬ CỦA NGƯỜI HỌC
#
#
# I. MỤC TIÊU VÀ NGUYÊN TẮC: Bô ̣ Quy tắc ứng xử của người học (go ̣ i tắt là
# “Quy tắc này”) đươ ̣ c ban h ành nhằm tạo lập môi trường học tập, nghiên cứu
# bình đẳng, công bằng, văn minh và hiệu quả. Người học được tôn trọng, có quyền
# tự do ứng xử theo nguyên tắc tuyê ̣ t đối tuân thủ pháp luật, tôn tro ̣ ng
# quyền và lợi ích hợp pháp của Nhà nước, Nhà trường và của các tổ chức, cá
# nhân khác. Quy tắc này bao gồm những nguyên tắc cơ bản trong ứng xử của người
# học trong phạm vi Trường Đa ̣ i ho ̣ c Tôn Đ ức Thắng (go ̣ i t ắt là
# “Trường” hoă ̣ c “Nhà trường”) và trong một số quan hệ xã hội khác mà Quy tắc
# này điều chỉnh. Quy tắc này và Quy chế Công tác sinh viên, Quy chế quản lý
# người học trình độ thạc sĩ, tiến sĩ là cơ sở pháp lý để người học có thể thực
# hiện quyền cơ bản và chịu các trách nhiệm trong học tập, ứng xử tại Trường và
# ...

# %%
def clean_more(text):
    # Bước 1: Kiểm tra nếu có các từ viết hoa liên tục thì bỏ qua xử lý
    if re.search(r'\b([A-Z]{2,}\s+){2,}[A-Z]{2,}\b', text):
        # Trường hợp có từ viết hoa liên tục, trả về text gốc
        return text

    # Bước 2: Loại bỏ khoảng trắng không cần thiết trước các dấu thanh và xung quanh các chữ cái đơn lẻ
    text = re.sub(r'(\w)\s+([̣̀́̉̃])', r'\1\2', text)  # Xóa khoảng trắng giữa từ và dấu thanh
    text = re.sub(r'([̣̀́̉̃])\s+(\w)', r'\1\2', text)  # Xóa khoảng trắng giữa dấu thanh và từ tiếp theo

    # Bước 4: Xóa khoảng trắng không cần thiết trong các từ có dấu tiếng Việt
    text = re.sub(r'(\w)\s+([̣̀́̉̃]\w)', r'\1\2', text)  # Xóa khoảng trắng giữa từ và dấu thanh
    text = re.sub(r'\b(\w)\s(\w)\b', r'\1\2', text)  # Áp dụng cho các trường hợp khác

    # Bước 5: Chuẩn hóa một số lỗi mã hóa phổ biến trong tiếng Việt (nếu cần)
    def normalize_vietnamese_text(text):
        replacements = {
            "à": "à", "á": "á", "ả": "ả", "ã": "ã", "ạ": "ạ",
            "ầ": "ầ", "ấ": "ấ", "ẩ": "ẩ", "ẫ": "ẫ", "ậ": "ậ",
            "ằ": "ằ", "ắ": "ắ", "ẳ": "ẳ", "ẵ": "ẵ", "ặ": "ặ",
            "è": "è", "é": "é", "ẻ": "ẻ", "ẽ": "ẽ", "ẹ": "ẹ",
            "ò": "ò", "ó": "ó", "ỏ": "ỏ", "õ": "õ", "ọ": "ọ",
            "ồ": "ồ", "ố": "ố", "ổ": "ổ", "ỗ": "ỗ", "ộ": "ộ",
            "ờ": "ờ", "ớ": "ớ", "ở": "ở", "ỡ": "ỡ", "ợ": "ợ",
            "ù": "ù", "ú": "ú", "ủ": "ủ", "ũ": "ũ", "ụ": "ụ",
            "ừ": "ừ", "ứ": "ứ", "ử": "ử", "ữ": "ữ", "ự": "ự",
            "ì": "ì", "í": "í", "ỉ": "ỉ", "ĩ": "ĩ", "ị": "ị",
            "ỳ": "ỳ", "ý": "ý", "ỷ": "ỷ", "ỹ": "ỹ", "ỵ": "ỵ"
        }
        for wrong, correct in replacements.items():
            text = text.replace(wrong, correct)
        return text

    text = normalize_vietnamese_text(text)

    # Bước 6: Gộp các dòng văn bản thành một câu hoàn chỉnh
    text = text.replace('\n', ' ')

    # Xóa khoảng trắng thừa nếu có
    text = re.sub(r'\s+', ' ', text).strip()

    return text


te = clean_more(formatted_text)
print(te)
# Out:
# Page 1: BỘ QUY TẮC ỨNG XỬ CỦA NGƯỜI HỌC I. MỤC TIÊU VÀ NGUYÊN TẮC: BộQuy tắc ứng xử của người học (gọi tắt là “Quy tắc này”) được ban hành nhằm tạo lập môi trường học tập, nghiên cứu bình đẳng, công bằng, văn minh và hiệu quả. Người học được tôn trọng, có quyền tự do ứng xử theo nguyên tắc tuyệt đối tuân thủpháp luật, tôn trọng quyền và lợi ích hợp pháp của Nhànước, Nhà trường và của các tổchức, cá nhân khác. Quy tắc này bao gồm những nguyên tắc cơ bản trong ứng xử của người học trong phạm vi Trường Đại học Tôn Đức Thắng (gọit ắt là “Trường” hoặc “Nhà trường”) và trong một số quan hệ xã hội khác mà Quy tắc này điều chỉnh. Quy tắc này và Quy chế Công tác sinh viên, Quy chế quản lý người học trình độ thạc sĩ, tiến sĩ là cơ sở pháp lý để người học có thể thực hiện quyền cơ bản và chịu các trách nhiệm trong học tập, ứng xử tại Trường và trong các quan hệ xã hội. Trong trường hợp người học có những hành vi ứng xử đáng khen, Nhà trường áp dụng các quy định về khen thưởng để tuyên dương và
# ...

# %%
import re
from textwrap import fill


def process_text(input_text):
    """
    Hàm gộp để định dạng và làm sạch văn bản:
    - Định dạng tiêu đề, các mục lớn, nhỏ và con.
    - Làm sạch các khoảng trắng không cần thiết và chuẩn hóa văn bản tiếng Việt.
    - Bỏ qua xử lý nếu phát hiện chuỗi từ viết hoa liên tục.
    """

    # Bước 1: Bỏ qua xử lý nếu phát hiện từ viết hoa liên tục
    if re.search(r'\b([A-Z]{2,}\s+){2,}[A-Z]{2,}\b', input_text):
        return input_text

    # Bước 2: Loại bỏ khoảng trắng thừa và gộp các dòng bị ngắt
    text = re.sub(r'\n+', ' ', input_text)  # Gộp các dòng
    text = re.sub(r'\s{2,}', ' ', text)  # Loại bỏ khoảng trắng thừa

    # Bước 3: Định dạng văn bản
    # Format tiêu đề chính
    text = re.sub(r'(BỘ QUY TẮC ỨNG XỬ CỦA NGƯỜI HỌC)', r'\n\1\n', text)

    # Format các mục lớn: "I.", "II.", ...
    text = re.sub(r'([IVXLCDM]+\.)', r'\n\n\1', text)

    # Format các mục nhỏ: "1.", "2.", ...
    text = re.sub(r'(\d+\.)', r'\n\1', text)

    # Format các mục con: "a)", "b)", ...
    text = re.sub(r'([a-z]\))', r'\n\1', text)

    # Bước 4: Làm sạch khoảng trắng không cần thiết quanh dấu thanh
    text = re.sub(r'(\w)\s+([̣̀́̉̃])', r'\1\2', text)  # Xóa khoảng trắng giữa từ và dấu thanh
    text = re.sub(r'([̣̀́̉̃])\s+(\w)', r'\1\2', text)  # Xóa khoảng trắng giữa dấu thanh và từ tiếp theo
    text = re.sub(r'(\w)\s+([̣̀́̉̃]\w)', r'\1\2', text)  # Xóa khoảng trắng giữa từ và dấu thanh
    text = re.sub(r'\b(\w)\s(\w)\b', r'\1\2', text)  # Áp dụng cho trường hợp đơn lẻ

    # Bước 5: Chuẩn hóa mã hóa tiếng Việt
    def normalize_vietnamese_text(text):
        replacements = {
            "à": "à", "á": "á", "ả": "ả", "ã": "ã", "ạ": "ạ",
            "ầ": "ầ", "ấ": "ấ", "ẩ": "ẩ", "ẫ": "ẫ", "ậ": "ậ",
            "ằ": "ằ", "ắ": "ắ", "ẳ": "ẳ", "ẵ": "ẵ", "ặ": "ặ",
            "è": "è", "é": "é", "ẻ": "ẻ", "ẽ": "ẽ", "ẹ": "ẹ",
            "ò": "ò", "ó": "ó", "ỏ": "ỏ", "õ": "õ", "ọ": "ọ",
            "ồ": "ồ", "ố": "ố", "ổ": "ổ", "ỗ": "ỗ", "ộ": "ộ",
            "ờ": "ờ", "ớ": "ớ", "ở": "ở", "ỡ": "ỡ", "ợ": "ợ",
            "ù": "ù", "ú": "ú", "ủ": "ủ", "ũ": "ũ", "ụ": "ụ",
            "ừ": "ừ", "ứ": "ứ", "ử": "ử", "ữ": "ữ", "ự": "ự",
            "ì": "ì", "í": "í", "ỉ": "ỉ", "ĩ": "ĩ", "ị": "ị",
            "ỳ": "ỳ", "ý": "ý", "ỷ": "ỷ", "ỹ": "ỹ", "ỵ": "ỵ"
        }
        for wrong, correct in replacements.items():
            text = text.replace(wrong, correct)
        return text

    text = normalize_vietnamese_text(text)

    # Bước 6: Gói nội dung dài thành các dòng tối đa 80 ký tự
    lines = text.splitlines()
    wrapped_lines = [fill(line.strip(), width=80) if line.strip() else line for line in lines]

    # Bước 7: Kết hợp lại thành văn bản hoàn chỉnh
    return "\n".join(wrapped_lines).strip()


# Ví dụ văn bản đầu vào
input_text = """
Page 1:
HƯỚNG DẪN HỌC BỔNG, KHEN THƯỞNG
, HỖ TRỢ NGƯỜI HỌC; 
HỌC BỔNG HỖ TRỢ CHO CỘNG ĐỒNG VÀ HỖ TRỢ KHÁC
I. HỌC BỔNG TÂN SINH VIÊN (KHÓA TUYỂN SINH NĂM 2024)
1. Học bổng Thủ khoa đầu vào
1.1. Đối tượng: Sinh viên trúng tuyển và nhập học tại Trường, Phân hiệu thuộc 
Trường trong đợt tuyển sinh đại học năm 2024
.
1.2. Điều kiện và mức xét cấp học bổng: 
- Sinh viên đạt điểm xét tuyển cao nhất tính theo điểm thi tốt nghiệp trung học 
phổ thông (THPT) năm 2024 của tất cả phương thức xét tuyển (không tính điểm ưu 
tiên tuyển sinh) sẽ được cấp học bổng toàn phần (100% học phí) năm học 2024 
- 2025 
theo khung chương trình đào tạo tiêu chuẩn
.
"""

# Chạy hàm xử lý văn bản
processed_text = process_text(input_text)

# In ra kết quả
print(processed_text)
# Out:
# Page 1: HƯỚNG DẪN HỌC BỔNG, KHEN THƯỞNG , HỖ TRỢ NGƯỜI HỌC; HỌC BỔNG HỖ TRỢ CHO
# CỘNG ĐỒNG VÀ HỖ TRỢ KHÁC
#
# I. HỌC BỔNG TÂN SINH VIÊN (KHÓA TUYỂN SINH NĂM 2024)
# 1. Học bổng Thủ khoa đầu vào
# 1.
# 1. Đối tượng: Sinh viên trúng tuyển và nhập học tại Trường, Phân hiệu thuộc
# Trường trong đợt tuyển sinh đại học năm 2024 .
# 1.
# 2. Điều kiện và mức xét cấp học bổng: - Sinh viên đạt điểm xét tuyển cao nhất
# tính theo điểm thi tốt nghiệp trung học phổ thông (THPT) năm 2024 của tất cả
# phương thức xét tuyển (không tính điểm ưu tiên tuyển sin
# h) sẽ được cấp học bổng toàn phần (100% học phí) năm học 2024 - 2025 theo khung
# chương trình đào tạo tiêu chuẩn .

# %% [markdown]
# # Clean data

# %%
import os
import re
from textwrap import fill

# Hàm xử lý văn bản
def process_text(input_text):
    if re.search(r'\b([A-Z]{2,}\s+){2,}[A-Z]{2,}\b', input_text):
        return input_text

    text = re.sub(r'(Page\s*\d+:)', r'\1\n', input_text)
    text = re.sub(r'\n+', ' ', text)  # Gộp các dòng
    text = re.sub(r'\s{2,}', ' ', text)  # Loại bỏ khoảng trắng thừa
    text = re.sub(r'(BỘ QUY TẮC ỨNG XỬ CỦA NGƯỜI HỌC)', r'\n\1\n', text)
    text = re.sub(r'([IVXLCDM]+\.)', r'\n\n\1', text)
    text = re.sub(r'(\d+\.)', r'\n\1', text)
    text = re.sub(r'([a-z]\))', r'\n\1', text)
    text = re.sub(r'(\w)\s+([̣̀́̉̃])', r'\1\2', text)
    text = re.sub(r'([̣̀́̉̃])\s+(\w)', r'\1\2', text)
    text = re.sub(r'(\w)\s+([̣̀́̉̃]\w)', r'\1\2', text)
    text = re.sub(r'\b(\w)\s(\w)\b', r'\1\2', text)

    def normalize_vietnamese_text(text):
        replacements = {
            "à": "à", "á": "á", "ả": "ả", "ã": "ã", "ạ": "ạ",
            "ầ": "ầ", "ấ": "ấ", "ẩ": "ẩ", "ẫ": "ẫ", "ậ": "ậ",
            "ằ": "ằ", "ắ": "ắ", "ẳ": "ẳ", "ẵ": "ẵ", "ặ": "ặ",
            "è": "è", "é": "é", "ẻ": "ẻ", "ẽ": "ẽ", "ẹ": "ẹ",
            "ò": "ò", "ó": "ó", "ỏ": "ỏ", "õ": "õ", "ọ": "ọ",
            "ồ": "ồ", "ố": "ố", "ổ": "ổ", "ỗ": "ỗ", "ộ": "ộ",
            "ờ": "ờ", "ớ": "ớ", "ở": "ở", "ỡ": "ỡ", "ợ": "ợ",
            "ù": "ù", "ú": "ú", "ủ": "ủ", "ũ": "ũ", "ụ": "ụ",
            "ừ": "ừ", "ứ": "ứ", "ử": "ử", "ữ": "ữ", "ự": "ự",
            "ì": "ì", "í": "í", "ỉ": "ỉ", "ĩ": "ĩ", "ị": "ị",
            "ỳ": "ỳ", "ý": "ý", "ỷ": "ỷ", "ỹ": "ỹ", "ỵ": "ỵ"
        }
        for wrong, correct in replacements.items():
            text = text.replace(wrong, correct)
        return text

    text = normalize_vietnamese_text(text)

    lines = text.splitlines()
    wrapped_lines = [fill(line.strip(), width=80) if line.strip() else line for line in lines]

    return "\n".join(wrapped_lines).strip()

# Đường dẫn thư mục gốc
input_dir = r"E:\LLM_clone\Tdtu-chatbot\notebooks\Crawldata\data"
output_dir = r"E:\LLM_clone\Tdtu-chatbot\notebooks\Crawldata\data_cleaned_11"

# Tạo thư mục data_cleaned nếu chưa tồn tại
os.makedirs(output_dir, exist_ok=True)

# Duyệt qua từng thư mục pageX
for page_folder in os.listdir(input_dir):
    page_path = os.path.join(input_dir, page_folder)
    if os.path.isdir(page_path):
        # Tạo thư mục tương ứng trong data_cleaned
        cleaned_page_path = os.path.join(output_dir, page_folder)
        os.makedirs(cleaned_page_path, exist_ok=True)

        # Duyệt qua các file txt trong thư mục
        for file_name in os.listdir(page_path):
            if file_name.endswith(".txt"):
                file_path = os.path.join(page_path, file_name)
                
                # Kiểm tra nếu file không rỗng
                if os.path.getsize(file_path) > 0:
                    with open(file_path, "r", encoding="utf-8") as file:
                        content = file.read()
                    
                    # Xử lý văn bản
                    cleaned_content = process_text(content)

                    # Lưu văn bản đã xử lý vào thư mục data_cleaned
                    cleaned_file_path = os.path.join(cleaned_page_path, file_name)
                    with open(cleaned_file_path, "w", encoding="utf-8") as cleaned_file:
                        cleaned_file.write(cleaned_content)

# %%
import os
import re
from textwrap import fill

# Hàm xử lý văn bản
def process_text(input_text):
    if re.search(r'\b([A-Z]{2,}\s+){2,}[A-Z]{2,}\b', input_text):
        return input_text

    text = re.sub(r'\n+', ' ', input_text)  # Gộp các dòng
    text = re.sub(r'\s{2,}', ' ', text)  # Loại bỏ khoảng trắng thừa
    text = re.sub(r'(BỘ QUY TẮC ỨNG XỬ CỦA NGƯỜI HỌC)', r'\n\1\n', text)
    text = re.sub(r'([IVXLCDM]+\.)', r'\n\n\1', text)
    text = re.sub(r'(\d+\.)', r'\n\1', text)
    text = re.sub(r'([a-z]\))', r'\n\1', text)
    text = re.sub(r'(\w)\s+([̣̀́̉̃])', r'\1\2', text)
    text = re.sub(r'([̣̀́̉̃])\s+(\w)', r'\1\2', text)
    text = re.sub(r'(\w)\s+([̣̀́̉̃]\w)', r'\1\2', text)
    text = re.sub(r'\b(\w)\s(\w)\b', r'\1\2', text)

    def normalize_vietnamese_text(text):
        replacements = {
            "à": "à", "á": "á", "ả": "ả", "ã": "ã", "ạ": "ạ",
            "ầ": "ầ", "ấ": "ấ", "ẩ": "ẩ", "ẫ": "ẫ", "ậ": "ậ",
            "ằ": "ằ", "ắ": "ắ", "ẳ": "ẳ", "ẵ": "ẵ", "ặ": "ặ",
            "è": "è", "é": "é", "ẻ": "ẻ", "ẽ": "ẽ", "ẹ": "ẹ",
            "ò": "ò", "ó": "ó", "ỏ": "ỏ", "õ": "õ", "ọ": "ọ",
            "ồ": "ồ", "ố": "ố", "ổ": "ổ", "ỗ": "ỗ", "ộ": "ộ",
            "ờ": "ờ", "ớ": "ớ", "ở": "ở", "ỡ": "ỡ", "ợ": "ợ",
            "ù": "ù", "ú": "ú", "ủ": "ủ", "ũ": "ũ", "ụ": "ụ",
            "ừ": "ừ", "ứ": "ứ", "ử": "ử", "ữ": "ữ", "ự": "ự",
            "ì": "ì", "í": "í", "ỉ": "ỉ", "ĩ": "ĩ", "ị": "ị",
            "ỳ": "ỳ", "ý": "ý", "ỷ": "ỷ", "ỹ": "ỹ", "ỵ": "ỵ"
        }
        for wrong, correct in replacements.items():
            text = text.replace(wrong, correct)
        return text

    text = normalize_vietnamese_text(text)

    lines = text.splitlines()
    wrapped_lines = [fill(line.strip(), width=80) if line.strip() else line for line in lines]

    return "\n".join(wrapped_lines).strip()

# Đường dẫn thư mục gốc
input_dir = r"E:\LLM_clone\Tdtu-chatbot\notebooks\Crawldata\data_new"
output_dir = r"E:\LLM_clone\Tdtu-chatbot\notebooks\Crawldata\data_cleaned_2"

# Tạo thư mục data_cleaned nếu chưa tồn tại
os.makedirs(output_dir, exist_ok=True)

# Duyệt qua các file txt trong thư mục gốc
for file_name in os.listdir(input_dir):
    if file_name.endswith(".txt"):
        file_path = os.path.join(input_dir, file_name)

        # Kiểm tra nếu file không rỗng
        if os.path.getsize(file_path) > 0:
            with open(file_path, "r", encoding="utf-8") as file:
                content = file.read()

            # Xử lý văn bản
            cleaned_content = process_text(content)

            # Lưu văn bản đã xử lý vào thư mục data_cleaned
            cleaned_file_path = os.path.join(output_dir, file_name)
            with open(cleaned_file_path, "w", encoding="utf-8") as cleaned_file:
                cleaned_file.write(cleaned_content)

# %% [markdown]
# # Move empty txt

# %%
import os
import shutil

# Đường dẫn tới folder chứa các file .txt
source_folder = r"E:\LLM_clone\Tdtu-chatbot\notebooks\Crawldata\data_new"

# Đường dẫn tới folder "empty" cùng cấp với "data_new"
empty_folder_new = os.path.join(os.path.dirname(source_folder), "empty")

# Định nghĩa các nội dung được coi là "trống"
placeholder_lines = {"Page 1:", "Page 2:", ""}  # Nội dung không đáng kể

# Tạo folder "empty" cùng cấp với "data_new" (nếu chưa tồn tại)
os.makedirs(empty_folder_new, exist_ok=True)

# Lấy danh sách các file .txt trong thư mục nguồn
files = [f for f in os.listdir(source_folder) if f.endswith(".txt")]

# Kiểm tra các file và di chuyển các file chỉ chứa nội dung không đáng kể
for file in files:
    file_path = os.path.join(source_folder, file)
    if os.path.isfile(file_path):
        try:
            with open(file_path, 'r', encoding='utf-8') as f:
                content = f.read().strip()
            # Nếu nội dung chỉ bao gồm các dòng trong placeholder_lines, di chuyển file
            if all(line in placeholder_lines for line in content.splitlines()):
                shutil.move(file_path, os.path.join(empty_folder_new, file))
        except PermissionError:
            print(f"PermissionError: Cannot process file {file_path}. It might be in use.")

# %% [markdown]
# ## Edit page and 1 . -> 1.

# %%
# Load and process the input text
input_text = """
Page 1:
BỘ QUY TẮC ỨNG XỬ CỦA NGƯỜI HỌC

I. MỤC TIÊU VÀ NGUYÊN TẮC: 1 . BộQuy tắc ứng xử của người học (gọi tắt là “Quy
tắc này”) được ban hành nhằm tạo lập môi trường học tập, nghiên cứu bình đẳng,
công bằng, văn minh và hiệu quả. Người học được tôn trọng, có quyền tự do ứng xử
theo nguyên tắc tuyệt đối tuân thủpháp luật, tôn trọng quyền và lợi ích hợp
pháp của Nhànước, Nhà trường và của các tổchức, cá nhân khác . 2 . Quy tắc này
bao gồm những nguyên tắc cơ bản trong ứng xử của người học trong phạm vi Trường
Đại học Tôn Đức Thắng (gọit ắt là “Trường” hoặc “Nhà trường”) và trong một số
quan hệ xã hội khác mà Quy tắc này điều chỉnh . 3 . Quy tắc này và Quy chế Công
tác sinh viên, Quy chế quản lý người học trình độ thạc sĩ, tiến sĩ là cơ sở pháp
lý để người học có thể thực hiện quyền cơ bản và chịu các trách nhiệm trong học
tập, ứng xử tại Trường và trong các quan hệ xã hội . 4 . Trong trường hợp người
học có những hành vi ứng xử đáng khen, Nhà trường áp dụng các quy định về khen
thưởng để tuyên dương và tặng thưởng . 5 . Trong trường hợp người học có hành vi
ứng xử vi phạmpháp luật ho ặc/vàvi phạm Quy tắc này, Nhà trường áp dụng Quy chế
Công tác sinh viên (đối với người học trình độ đại họ
c) hoặc Quy chế quản lý người học trình độ thạc sĩ, tiến sĩ (đối với người học
trình độ thạc sĩ, tiến sĩ) để xử lý.
3. TÔN TRỌNG QUYỀN TỰ DO CÁ NHÂN:
a) Tự do cá nhân là quyền cơ bản của công dân được Hiến pháp vàpháp luật quy
định .
b) Người học được đảm bảo: (1) các quyền tự do cánhân do Hiến pháp vàpháp
luậtquy địnhđược thực hiện và tôn trọng triệt để; (2) người học là chủthểduy
nhất cóquyền quyết định công bố các thông tin cá nhân cho người khác. Để tránh
nhầm lẫn, các thông tin về học tập, sinh hoạt của người học được cung cấp cho
phụ huynh theo yêu cầu của gia đình và/hoặc của người học; (3) mọi hành vi xâm
phạm thân thể, nhân phẩm của người học một cách trực tiếp hoặc gián tiếp đều
phải bị xử lý theo đúng pháp luật và nội quy của Nhà trường. Page 3: 3
c) Để đảm bảo quyền tự do của người khác, người học có trách nhiệm: (1) tôn
trọng quyền tự do cá nhân, thông tin cá nhân của người khác; (2) tôn trọng mọi
sự khác biệt nếu sự khác biệt đó không là hành vi vi phạm pháp luật, phù hợp với
chuẩn mực đạo đức và quy chế của Nhà trường; (3) không có bất kỳ hành vi trực
tiếp hoặc gián tiếp xâm phạm đến quyền tự do cá nhân của người khác.
"""

import re

# Replace "1 ." or "2 ." with "1." or "2."
text_cleaned = re.sub(r"(\d) \.", r"\1.", input_text)

# Ensure each "Page X:" starts on a new line
text_cleaned = re.sub(r"(Page \d+:)", r"\n\1", text_cleaned)

print(text_cleaned)
# Out:
# Page 1:
# BỘ QUY TẮC ỨNG XỬ CỦA NGƯỜI HỌC
#
# I. MỤC TIÊU VÀ NGUYÊN TẮC: 1. BộQuy tắc ứng xử của người học (gọi tắt là “Quy
# tắc này”) được ban hành nhằm tạo lập môi trường học tập, nghiên cứu bình đẳng,
# công bằng, văn minh và hiệu quả. Người học được tôn trọng, có quyền tự do ứng xử
# theo nguyên tắc tuyệt đối tuân thủpháp luật, tôn trọng quyền và lợi ích hợp
# pháp của Nhànước, Nhà trường và của các tổchức, cá nhân khác . 2. Quy tắc này
# bao gồm những nguyên tắc cơ bản trong ứng xử của người học trong phạm vi Trường
# Đại học Tôn Đức Thắng (gọit ắt là “Trường” hoặc “Nhà trường”) và trong một số
# quan hệ xã hội khác mà Quy tắc này điều chỉnh . 3. Quy tắc này và Quy chế Công
# tác sinh viên, Quy chế quản lý người học trình độ thạc sĩ, tiến sĩ là cơ sở pháp
# lý để người học có thể thực hiện quyền cơ bản và chịu các trách nhiệm trong học
# tập, ứng xử tại Trường và trong các quan hệ xã hội . 4. Trong trường hợp người
# ...

# %%
import re

# File paths
file_path = r"E:\LLM_clone\Tdtu-chatbot\notebooks\Crawldata\cleaned_text_output7.txt"
output_file_path = r"E:\LLM_clone\Tdtu-chatbot\notebooks\Crawldata\cleaned_text_output8.txt"

# Process the file
try:
    with open(file_path, "r", encoding="utf-8") as file:
        file_content = file.read()

    # Replace "1 ." or "2 ." with "1." or "2."
    processed_content = re.sub(r"(\d) \.", r"\1.", file_content)

    # Ensure each "Page X:" starts on a new line
    processed_content = re.sub(r"(Page \d+:)", r"\n\1\n", processed_content)

    # Ensure ":" is followed by a newline (but only one) and text starts immediately after
    processed_content = re.sub(r":\s*\n+", r":\n", processed_content)

    # Ensure email formatting: no extra newlines before or after
    processed_content = re.sub(r"(\S+@\S+\.\S+)\s*\n+", r"\1\n", processed_content)

    with open(output_file_path, "w", encoding="utf-8") as output_file:
        # Writing the processed content
        output_file.write(processed_content)

    print(f"The processed content has been saved to: {output_file_path}")

    # Display the processed content
    print(processed_content[:1000])  # Displaying only the first 1000 characters for brevity
except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# The processed content has been saved to: E:\LLM_clone\Tdtu-chatbot\notebooks\Crawldata\cleaned_text_output8.txt
#
# Page 1:
# 1. Phòng Tổ chức hành chính: - Tham mưu cho nhà trường về công tác tổ chức; cán
# bộ, hành chính, tổng hợp, công tác bảo vệ nội bộ; phát triển chế độ, chính sách;
# phát triển nguồn nhân lực, qui hoạch đào tạo cán bộ quản lý, giảng viên, viên
# chức... - Kiểm tra, rà soát, đảm bảo chính phòng và các đơn vị khác trong trường
# thực hiện đúng chế độ chính sách đối với viên chức, giảng viên; tổ chức công tác
# lưu trữ, sao y các văn bằng chứng chỉ do nhà trường cấp. - Liên hệ đăng ký làm
# việc với Ban giám hiệu, giải đáp các thông tin về bảo hiểm y tế, bảo vệ, Ký túc
# xá. Thông tin liên hê:̣ - Sơ cứu, thông tin bảo hiểm y tế: Tầng trệt Nhà Thi đấu
# – ĐT: (028) 22137081, cơ sở Tân Phong. - Sao y văn bằng chứng chỉ, liên hệ làm
# việc: Phòng A0009, cơ sở Tân Phong. - Điện thoại: (028) 37755035 - Email:
# phongtchc@tdtu.edu.vn
# ...

# %%
import os

# Đường dẫn thư mục chứa các tệp trống và tệp error.txt
empty_folder = r"E:\LLM_clone\Tdtu-chatbot\notebooks\Crawldata\empty"
error_file_path = r"E:\LLM_clone\Tdtu-chatbot\notebooks\Crawldata\error.txt"

# Lấy danh sách các tệp rỗng
empty_files = []

for filename in os.listdir(empty_folder):
    if filename.endswith(".txt"):  # Chỉ xử lý các tệp .txt
        file_path = os.path.join(empty_folder, filename)
        if os.path.getsize(file_path) == 0:  # Kiểm tra nếu tệp rỗng
            empty_files.append(filename)

# Ghi tên các tệp rỗng vào error.txt
with open(error_file_path, "w", encoding="utf-8") as error_file:
    for empty_file in empty_files:
        error_file.write(empty_file + "\n")

print(f"Đã ghi tên các tệp rỗng vào {error_file_path}:")
print("\n".join(empty_files))
# Out:
# Đã ghi tên các tệp rỗng vào E:\LLM_clone\Tdtu-chatbot\notebooks\Crawldata\error.txt:
