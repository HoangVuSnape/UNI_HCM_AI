# %% [markdown]
# # Import lib

# %%
import sqlite3
import pandas as pd
import os

# %% [markdown]
# # Functions

# %%
def read_sql_query(sql, db):
    conn = sqlite3.connect(db)
    cur = conn.cursor()
    cur.execute(sql)
    rows = cur.fetchall()
    for row in rows:
        print(row)
    conn.close()

# %% [markdown]
# # Create table

# %%
# Function to create database schema
def create_database():
    with sqlite3.connect('university_admissions.db') as conn:
        cursor = conn.cursor()

        # Create table: universities
        cursor.execute('''
        CREATE TABLE IF NOT EXISTS universities (
            code TEXT PRIMARY KEY,
            short_name TEXT,
            full_name TEXT
        )
        ''')

        # Create table: admission_methods
        cursor.execute('''
        CREATE TABLE IF NOT EXISTS admission_methods (
            id INTEGER PRIMARY KEY,
            name TEXT
        )
        ''')

        # Create table: admission_scores
        cursor.execute('''
        CREATE TABLE IF NOT EXISTS admission_scores (
            id INTEGER PRIMARY KEY,
            university_code TEXT NOT NULL,
            major_code TEXT NOT NULL,
            major_name TEXT NOT NULL,
            admission_method_id INTEGER NOT NULL,
            year INTEGER NOT NULL,
            subject_combination TEXT,
            score REAL,
            note TEXT,
            FOREIGN KEY (university_code) REFERENCES universities (code),
            FOREIGN KEY (admission_method_id) REFERENCES admission_methods (id)
        )
        ''')

        conn.commit()

# %%
create_database()

# %% [markdown]
# # Insert data

# %%
# Import data from Excel files
file_path_universities = r'E:\LLM_clone\Tdtu-chatbot\notebooks\DataSQL\Danh_sach_truong_dai_hoc.xlsx'
data_universities = pd.read_excel(file_path_universities)

file_path_admission_methods = r'E:\LLM_clone\Tdtu-chatbot\notebooks\DataSQL\admission_methods.xlsx'
data_admission_methods = pd.read_excel(file_path_admission_methods)

with sqlite3.connect('university_admissions.db') as conn:
    cursor = conn.cursor()

    # Insert data into universities table
    for index, row in data_universities.iterrows():
        cursor.execute('''
        INSERT OR IGNORE INTO universities (code, short_name, full_name)
        VALUES (?, ?, ?)
        ''', (row['Mã Trường'], row['Viết Tắt'], row['Tên Trường']))

    # Insert data into admission_methods table
    for index, row in data_admission_methods.iterrows():
        cursor.execute('''
        INSERT OR IGNORE INTO admission_methods (id, name)
        VALUES (?, ?)
        ''', (row['id'], row['name']))

    conn.commit()

# %%
read_sql_query('SELECT * FROM universities LIMIT 20;',
               "university_admissions.db")
# Out:
# ('QSB', 'BKU', 'Trường Đại học Bách Khoa TP. Hồ Chí Minh (Ho Chi Minh City University of Technology)')
# ('SPK', 'HCMUTE', 'Trường Đại học Sư phạm Kỹ thuật TP. Hồ Chí Minh (Ho Chi Minh City University of Technology and Education)')
# ('FPT', 'FPT', 'Trường Đại học FPT (FPT University)')
# ('NTS', 'FTU2', 'Trường Đại học Ngoại thương - Cơ sở 2 TP. Hồ Chí Minh (Foreign Trade University, Campus 2)')
# ('QST', 'HCMUS', 'Trường Đại học Khoa học Tự nhiên TP. Hồ Chí Minh (University of Science, Ho Chi Minh City)')
# ('TTD', 'TDTU', 'Trường Đại học Tôn Đức Thắng (Ton Duc Thang University)')
# ('KSA', 'UEH', 'Trường Đại học Kinh tế TP. Hồ Chí Minh (University of Economics Ho Chi Minh City)')
# ('DMS', 'UFM', 'Trường Đại học Tài chính - Marketing (University of Finance and Marketing)')
# ('QSC', 'UIT', 'Trường Đại học Công nghệ Thông tin TP. Hồ Chí Minh (University of Information Technology, Ho Chi Minh City)')
# ('DVL', 'VLU', 'Trường Đại học Văn Lang (Van Lang University)')
# ('YDS', 'UMP', 'Trường Đại học Y Dược TP. Hồ Chí Minh (University of Medicine and Pharmacy, Ho Chi Minh City)')
# ('TYS', 'PNTU', 'Trường Đại học Y khoa Phạm Ngọc Thạch (Pham Ngoc Thach University of Medicine)')
# ('MBS', 'OU', 'Trường Đại học Mở TP. Hồ Chí Minh (Ho Chi Minh City Open University)')
# ('NTT', 'NTTU', 'Trường Đại học Nguyễn Tất Thành (Nguyen Tat Thanh University)')
# ('SPS', 'HCMUE', 'Trường Đại học Sư phạm TP. Hồ Chí Minh (Ho Chi Minh City University of Education)')

# %%
# Corrected SQL query
query = 'SELECT * FROM universities WHERE code = "QSB" LIMIT 20;'

# Connect to the database and execute the query
with sqlite3.connect("university_admissions.db") as conn:
    df = pd.read_sql_query(query, conn)

# Display the result
print(df)
# Out:
#   code short_name                                          full_name
# 0  QSB        BKU  Trường Đại học Bách Khoa TP. Hồ Chí Minh (Ho C...

# %%
read_sql_query('SELECT * FROM admission_methods LIMIT 20;',
               "university_admissions.db")
# Out:
# (1, 'Thi THPT')
# (2, 'Học bạ - Kết quả học tập THPT đợt 1')
# (3, 'Học bạ - Kết quả học tập THPT đợt 2')
# (4, 'DGNL')
# (5, 'UTXT đợt 1')
# (6, 'UTXT đợt 2')
# (7, 'Xét riêng')

# %%
# Function to insert admission scores from folder structure
def insert_admission_scores_from_folders(base_path):
    """
    Insert admission scores from Excel files stored in a folder structure by university and year.

    :param base_path: The base directory containing university folders with year subfolders.
    """
    with sqlite3.connect('university_admissions.db') as conn:
        cursor = conn.cursor()

        # Traverse through each university folder
        for university_folder in os.listdir(base_path):
            university_path = os.path.join(base_path, university_folder)

            if os.path.isdir(university_path):  # Ensure it's a directory
                tables_path = os.path.join(university_path, "Tables")

                if os.path.isdir(tables_path):  # Ensure 'Tables' directory exists
                    # Traverse through each year folder within the 'Tables' directory
                    for year_folder in os.listdir(tables_path):
                        year_path = os.path.join(tables_path, year_folder)

                        if os.path.isdir(year_path):  # Ensure it's a directory
                            try:
                                year = int(year_folder)  # Parse year from folder name
                            except ValueError:
                                continue  # Skip if the folder name is not a year

                            # Traverse through each Excel file in the year folder
                            for file_name in os.listdir(year_path):
                                if file_name.endswith('.xlsx'):  # Only process Excel files
                                    file_path = os.path.join(year_path, file_name)
                                    admission_method = int(file_name[0])
                                    # Read the Excel file
                                    data = pd.read_excel(file_path)

                                    # Insert data into admission_scores table
                                    for index, row in data.iterrows():
                                        cursor.execute('''
                                        INSERT OR IGNORE INTO admission_scores (
                                            id, university_code, major_code, major_name, admission_method_id,
                                            year, subject_combination, score, note
                                        )
                                        VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
                                        ''', (
                                            None,  # Auto-increment ID
                                            university_folder,  # University code from folder name
                                            row['Mã ngành'],
                                            row['Tên ngành'],
                                            admission_method,  # Default admission method ID (e.g., Thi THPT)
                                            year,
                                            row['Tổ hợp'],
                                            row['Điểm chuẩn'],
                                            row['Ghi chú']
                                        ))

        conn.commit()

# %%
insert_admission_scores_from_folders(r'E:\LLM_clone\Tdtu-chatbot\notebooks\Data Tuyển sinh')

# %%
# Corrected SQL query
query = 'SELECT * FROM universities '

# Connect to the database and execute the query
with sqlite3.connect("university_admissions.db") as conn:
    df = pd.read_sql_query(query, conn)

# Display the result
print(df)
# Out:
#    code short_name                                          full_name
# 0   QSB        BKU  Trường Đại học Bách Khoa TP. Hồ Chí Minh (Ho C...
# 1   SPK     HCMUTE  Trường Đại học Sư phạm Kỹ thuật TP. Hồ Chí Min...
# 2   FPT        FPT                Trường Đại học FPT (FPT University)
# 3   NTS       FTU2  Trường Đại học Ngoại thương - Cơ sở 2 TP. Hồ C...
# 4   QST      HCMUS  Trường Đại học Khoa học Tự nhiên TP. Hồ Chí Mi...
# 5   TTD       TDTU  Trường Đại học Tôn Đức Thắng (Ton Duc Thang Un...
# 6   KSA        UEH  Trường Đại học Kinh tế TP. Hồ Chí Minh (Univer...
# 7   DMS        UFM  Trường Đại học Tài chính - Marketing (Universi...
# 8   QSC        UIT  Trường Đại học Công nghệ Thông tin TP. Hồ Chí ...
# 9   DVL        VLU      Trường Đại học Văn Lang (Van Lang University)
# 10  YDS        UMP  Trường Đại học Y Dược TP. Hồ Chí Minh (Univers...
# 11  TYS       PNTU  Trường Đại học Y khoa Phạm Ngọc Thạch (Pham Ng...
# 12  MBS         OU  Trường Đại học Mở TP. Hồ Chí Minh (Ho Chi Minh...
# 13  NTT       NTTU  Trường Đại học Nguyễn Tất Thành (Nguyen Tat Th...
# 14  SPS      HCMUE  Trường Đại học Sư phạm TP. Hồ Chí Minh (Ho Chi...

# %%
# Corrected SQL query
query = 'SELECT * FROM admission_scores;'

# Connect to the database and execute the query
with sqlite3.connect("university_admissions.db") as conn:
    df = pd.read_sql_query(query, conn)

# Display the result
df['university_code'].unique()
# Out:
# array(['TDTU', 'UEH'], dtype=object)

# %% [markdown]
# # View db

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1835 entries, 0 to 1834
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id                   1835 non-null   int64
#  1   university_code      1835 non-null   object
#  2   major_code           1835 non-null   object
#  3   major_name           1835 non-null   object
#  4   admission_method_id  1835 non-null   int64
#  5   year                 1835 non-null   int64
#  6   subject_combination  690 non-null    object
#  7   score                1834 non-null   object
#  8   note                 806 non-null    object
# dtypes: int64(3), object(6)
# memory usage: 129.2+ KB

# %%
df.isnull().sum()
# Out:
# id                        0
# university_code           0
# major_code                0
# major_name                0
# admission_method_id       0
# year                      0
# subject_combination    1145
# score                     1
# note                   1029
# dtype: int64

# %%
print(df['year'].unique())
print(df['admission_method_id'].unique())
# Out:
# [2021 2022 2023 2024]
# [1 2 3 5 6 4]

# %%
# Corrected SQL query
query = 'SELECT * FROM admission_scores'

# Connect to the database and execute the query
with sqlite3.connect("university_admissions.db") as conn:
    df = pd.read_sql_query(query, conn)

# Display the result
df["university_code"].unique()
# Out:
# array(['TDTU', 'UEH', 'FPT', 'FTU2', 'HCMUS', 'UFM', 'UIT'], dtype=object)

# %% [markdown]
# # upate db

# %%
# Function to insert admission scores from specific university folders
def insert_admission_scores_from_folders(base_path, allowed_universities):
    """
    Insert admission scores from Excel files stored in a folder structure by specific universities and year.

    :param base_path: The base directory containing university folders with year subfolders.
    """

    with sqlite3.connect('university_admissions.db') as conn:
        cursor = conn.cursor()

        # Traverse through each university folder
        for university_folder in os.listdir(base_path):
            university_path = os.path.join(base_path, university_folder)

            # Process only if the university is in the allowed list
            if university_folder in allowed_universities and os.path.isdir(university_path):
                tables_path = os.path.join(university_path, "Tables")

                if os.path.isdir(tables_path):  # Ensure 'Tables' directory exists
                    # Traverse through each year folder within the 'Tables' directory
                    for year_folder in os.listdir(tables_path):
                        year_path = os.path.join(tables_path, year_folder)

                        if os.path.isdir(year_path):  # Ensure it's a directory
                            try:
                                year = int(year_folder)  # Parse year from folder name
                            except ValueError:
                                continue  # Skip if the folder name is not a year

                            # Traverse through each Excel file in the year folder
                            for file_name in os.listdir(year_path):
                                if file_name.endswith('.xlsx'):  # Only process Excel files
                                    file_path = os.path.join(year_path, file_name)
                                    admission_method = int(file_name[0])  # Parse method from file name

                                    # Read the Excel file
                                    data = pd.read_excel(file_path)

                                    # Insert data into admission_scores table
                                    for index, row in data.iterrows():
                                        cursor.execute('''
                                        INSERT OR IGNORE INTO admission_scores (
                                            id, university_code, major_code, major_name, admission_method_id,
                                            year, subject_combination, score, note
                                        )
                                        VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
                                        ''', (
                                            None,  # Auto-increment ID
                                            university_folder,  # University code from folder name
                                            row['Mã ngành'],
                                            row['Tên ngành'],
                                            admission_method,  # Default admission method ID (e.g., Thi THPT)
                                            year,
                                            row['Tổ hợp môn'],
                                            row['Điểm chuẩn'],
                                            row['Ghi chú']
                                        ))

        conn.commit()

# %%
allowed_universities = {'FPT', 'FTU2', 'UFM', 'UIT', 'HCMUS'}
insert_admission_scores_from_folders(r'E:\LLM_clone\Tdtu-chatbot\notebooks\Data Tuyển sinh', allowed_universities)

# %% [markdown]
# ## Test
# - View data

# %%
# Corrected SQL query
query = 'SELECT * FROM admission_scores;'

# Connect to the database and execute the query
with sqlite3.connect("university_admissions.db") as conn:
    df = pd.read_sql_query(query, conn)

# Display the result
df
# Out:
#         id university_code major_code  \
# 0        1            TDTU    7220201
# 1        2            TDTU    7310630
# 2        3            TDTU   7310630Q
# 3        4            TDTU    7340101
# 4        5            TDTU    7340115
# ...    ...             ...        ...
# 2748  2749             UIT    7480107
# 2749  2750             UIT    7480201
# 2750  2751             UIT  7480201_N
# 2751  2752             UIT    7480202
# 2752  2753             UIT    75202a1
#
#                                              major_name  admission_method_id  \
# 0                                          Ngôn ngữ Anh                    1
# 1       Việt Nam học (Chuyên ngành: Du lịch và lữ hành)                    1
# 2     Việt Nam học (Chuyên ngành: Du lịch và quản lý...                    1
# 3     Quản trị kinh doanh (Chuyên ngành: Quản trị ng...                    1
# 4                                             Marketing                    1
# ...                                                 ...                  ...
# 2748                                   Trí tuệ nhân tạo                    4
# 2749                                Công nghệ thông tin                    4
# 2750                  Công nghệ thông tin (Việt - Nhật)                    4
# 2751                                  An toàn thông tin                    4
# 2752                                   Thiết kế vi mạch                    4
#
#       year subject_combination  score  \
# 0     2021            D01; D11  35,60
# 1     2021  A01; C00; C01; D01  33,30
# 2     2021  A01; C00; C01; D01  34,20
# 3     2021       A00; A01; D01  36,00
# 4     2021       A00; A01; D01  36,90
# ...    ...                 ...    ...
# 2748  2024                None  980.0
# 2749  2024                None  915.0
# 2750  2024                None  850.0
# 2751  2024                None  910.0
# 2752  2024                None  910.0
#
#                                                    note
# 0     Môn nhân hệ số 2, điều kiện: Anh\n Điểm trúng ...
# 1     Môn nhân hệ số 2, điều kiện: A01, D01: Anh C00...
# 2     Môn nhân hệ số 2, điều kiện: A01, D01: Anh C00...
# 3     Môn nhân hệ số 2, điều kiện: A00: Toán, A01, D...
# 4     Môn nhân hệ số 2, điều kiện: A00: Toán, A01, D...
# ...                                                 ...
# 2748                                               None
# 2749                                               None
# 2750                                               None
# 2751                                               None
# 2752                                               None
#
# [2753 rows x 9 columns]

# %%
# Keyword to filter major_name
keyword = 'ngôn ngữ'

# SQL query with filtering
query = f"SELECT * FROM admission_scores WHERE major_name LIKE '%{keyword}%';"

# Connect to the database and execute the query
with sqlite3.connect("university_admissions.db") as conn:
    df = pd.read_sql_query(query, conn)

# Display the filtered result
df["admission_method_id"].unique()
# Out:
# array([1, 2, 3, 5, 6, 4], dtype=int64)

# %%
query = f"SELECT * FROM admission_scores WHERE admission_method_id = 1 and year = 2021 and major_name LIKE '%{'ngôn ngữ anh'}%' and university_code = 'TDTU';"

# Connect to the database and execute the query
with sqlite3.connect("university_admissions.db") as conn:
    df = pd.read_sql_query(query, conn)

# Display the filtered result
df
# Out:
#    id university_code major_code                     major_name  \
# 0   1            TDTU    7220201                   Ngôn ngữ Anh
# 1  40            TDTU   F7220201  Ngôn ngữ Anh - Chất lượng cao
#
#    admission_method_id  year subject_combination  score  \
# 0                    1  2021            D01; D11  35,60
# 1                    1  2021            D01; D11  34,80
#
#                                                 note
# 0  Môn nhân hệ số 2, điều kiện: Anh\n Điểm trúng ...
# 1  Môn nhân hệ số 2, điều kiện: Anh\n Điểm trúng ...

# %%
query = f"SELECT * FROM admission_scores WHERE admission_method_id = 1 and year = 2021 and major_name = 'Ngôn ngữ Anh' and university_code = 'TDTU';"

# Connect to the database and execute the query
with sqlite3.connect("university_admissions.db") as conn:
    df = pd.read_sql_query(query, conn)

# Display the filtered result
df
# Out:
#    id university_code major_code    major_name  admission_method_id  year  \
# 0   1            TDTU    7220201  Ngôn ngữ Anh                    1  2021
#
#   subject_combination  score  \
# 0            D01; D11  35,60
#
#                                                 note
# 0  Môn nhân hệ số 2, điều kiện: Anh\n Điểm trúng ...

# %%
query = f"SELECT * FROM admission_scores WHERE admission_method_id = 4 and year = 2022 and university_code = 'UEH';"

# Connect to the database and execute the query
with sqlite3.connect("university_admissions.db") as conn:
    df = pd.read_sql_query(query, conn)

# Display the filtered result
df
# Out:
#       id university_code  major_code                            major_name  \
# 0   1430             UEH     7310101                               Kinh tế
# 1   1431             UEH     7310104                        Kinh tế đầu tư
# 2   1432             UEH     7340116                          Bất động sản
# 3   1433             UEH     7340404                     Quản trị nhân lực
# 4   1434             UEH     7620114                Kinh doanh nông nghiệp
# 5   1435             UEH     7340101                   Quản trị kinh doanh
# 6   1436             UEH     7340120                    Kinh doanh quốc tế
# 7   1437             UEH     7510605   Logistics và quản lý chuỗi cung ứng
# 8   1438             UEH     7340121                 Kinh doanh thương mại
# 9   1439             UEH     7340115                             Marketing
# 10  1440             UEH     7340201                 Tài chính - Ngân hàng
# 11  1441             UEH     7340204                              Bảo hiểm
# 12  1442             UEH     7340206                     Tài chính Quốc tế
# 13  1443             UEH     7340301                               Kế toán
# 14  1444             UEH  7340301_01         Chương trình Kế toán tích hợp
# 15  1445             UEH     7340302                             Kiểm toán
# 16  1446             UEH     7810103   Quản trị dịch vụ du lịch và lữ hành
# 17  1447             UEH     7810201                    Quản trị khách sạn
# 18  1448             UEH     7310108                          Toán kinh tế
# 19  1449             UEH     7310107                      Thống kê kinh tế
# 20  1450             UEH     7340405            Hệ thống thông tin quản lý
# 21  1451             UEH     7340122                    Thương mại điện tử
# 22  1452             UEH     7480109                      Khoa học dữ liệu
# 23  1453             UEH     7480103                     Kỹ thuật phần mềm
# 24  1454             UEH     7220201                          Ngôn ngữ Anh
# 25  1455             UEH     7380107                          Luật kinh tế
# 26  1456             UEH     7380101                                  Luật
# 27  1457             UEH     7340403                          Quản lý công
# 28  1458             UEH     7580104                      Kiến trúc đô thị
# 29  1459             UEH     7489001         Công nghệ và đổi mới sáng tạo
# 30  1460             UEH     7320106                Công nghệ truyền thông
# 31  1461             UEH     7340129                    Quản trị bệnh viện
#
#     admission_method_id  year subject_combination  score  note
# 0                     4  2022                None  900.0  None
# 1                     4  2022                None  870.0  None
# 2                     4  2022                None  850.0  None
# 3                     4  2022                None  900.0  None
# 4                     4  2022                None  800.0  None
# 5                     4  2022                None  860.0  None
# 6                     4  2022                None  930.0  None
# 7                     4  2022                None  950.0  None
# 8                     4  2022                None  900.0  None
# 9                     4  2022                None  940.0  None
# 10                    4  2022                None  845.0  None
# 11                    4  2022                None  800.0  None
# 12                    4  2022                None  920.0  None
# 13                    4  2022                None  830.0  None
# 14                    4  2022                None  830.0  None
# 15                    4  2022                None  890.0  None
# 16                    4  2022                None  820.0  None
# 17                    4  2022                None  820.0  None
# 18                    4  2022                None  800.0  None
# 19                    4  2022                None  830.0  None
# 20                    4  2022                None  880.0  None
# 21                    4  2022                None  940.0  None
# 22                    4  2022                None  920.0  None
# 23                    4  2022                None  900.0  None
# 24                    4  2022                None  860.0  None
# 25                    4  2022                None  860.0  None
# 26                    4  2022                None  880.0  None
# 27                    4  2022                None  800.0  None
# 28                    4  2022                None  800.0  None
# 29                    4  2022                None  800.0  None
# 30                    4  2022                None  910.0  None
# 31                    4  2022                None  850.0  None

# %%
# query = f"SELECT * FROM admission_scores WHERE admission_method_id = 1 and year = 2024 and major_name LIKE '%{'Trí tuệ nhân tạo'}%' and university_code = 'UIT';"
query = """
SELECT * \n
FROM admission_scores 
WHERE admission_method_id = 1 
  AND year = 2022 
  AND major_name LIKE '%trí tuệ nhân tạo%' 
  AND university_code = 'UIT';
"""

# Connect to the database and execute the query
with sqlite3.connect("university_admissions.db") as conn:
    df = pd.read_sql_query(query, conn)

# Display the filtered result
df
# Out:
#      id university_code major_code        major_name  admission_method_id  \
# 0  2682             UIT    7480107  Trí tuệ nhân tạo                    1
#
#    year subject_combination  score  note
# 0  2022     A00;A01;D01;D07   28.0  None

# %%
query = f"SELECT * FROM admission_scores WHERE admission_method_id = 1 \
     AND year = 2021 \
     AND university_code = 'TDTU';"

# Connect to the database and execute the query
with sqlite3.connect("university_admissions.db") as conn:
    df = pd.read_sql_query(query, conn)

# Display the filtered result
df
# Out:
#     id university_code major_code  \
# 0    1            TDTU    7220201
# 1    2            TDTU    7310630
# 2    3            TDTU   7310630Q
# 3    4            TDTU    7340101
# 4    5            TDTU    7340115
# 5    6            TDTU   7340101N
# 6    7            TDTU    7340120
# 7    8            TDTU    7340201
# 8    9            TDTU    7340301
# 9   10            TDTU    7380101
# 10  11            TDTU    7720201
# 11  12            TDTU    7220204
# 12  13            TDTU    7420201
# 13  14            TDTU    7520301
# 14  15            TDTU    7480101
# 15  16            TDTU    7480102
# 16  17            TDTU    7480103
# 17  18            TDTU    7520201
# 18  19            TDTU    7520207
# 19  20            TDTU    7520216
# 20  21            TDTU    7520114
# 21  22            TDTU    7580201
# 22  23            TDTU    7580101
# 23  24            TDTU    7210402
# 24  25            TDTU    7210403
# 25  26            TDTU    7210404
# 26  27            TDTU    7580108
# 27  28            TDTU    7340408
# 28  29            TDTU    7810301
# 29  30            TDTU    7810302
# 30  31            TDTU    7310301
# 31  32            TDTU    7760101
# 32  33            TDTU    7850201
# 33  34            TDTU    7510406
# 34  35            TDTU    7440301
# 35  36            TDTU    7460112
# 36  37            TDTU    7460201
# 37  38            TDTU    7580105
# 38  39            TDTU    7580205
# 39  40            TDTU   F7220201
# 40  41            TDTU  F7310630Q
# 41  42            TDTU   F7340101
# 42  43            TDTU   F7340115
# 43  44            TDTU  F7340101N
# 44  45            TDTU   F7340120
# 45  46            TDTU   F7340201
# 46  47            TDTU   F7340301
# 47  48            TDTU   F7380101
# 48  49            TDTU   F7420201
# 49  50            TDTU   F7480101
# 50  51            TDTU   F7480103
# 51  52            TDTU   F7520201
# 52  53            TDTU   F7520207
# 53  54            TDTU   F7520216
# 54  55            TDTU   F7580201
# 55  56            TDTU   F7210403
#
#                                            major_name  admission_method_id  \
# 0                                        Ngôn ngữ Anh                    1
# 1     Việt Nam học (Chuyên ngành: Du lịch và lữ hành)                    1
# 2   Việt Nam học (Chuyên ngành: Du lịch và quản lý...                    1
# 3   Quản trị kinh doanh (Chuyên ngành: Quản trị ng...                    1
# 4                                           Marketing                    1
# 5   Quản trị kinh doanh (Chuyên ngành: Quản trị nh...                    1
# 6                                  Kinh doanh quốc tế                    1
# 7                               Tài chính - Ngân hàng                    1
# 8                                             Kế toán                    1
# 9                                                Luật                    1
# 10                                           Dược học                    1
# 11                                Ngôn ngữ Trung Quốc                    1
# 12                                 Công nghệ sinh học                    1
# 13                                   Kỹ thuật hóa học                    1
# 14                                  Khoa học máy tính                    1
# 15              Mạng máy tính và truyền thông dữ liệu                    1
# 16                                  Kỹ thuật phần mềm                    1
# 17                                      Kỹ thuật điện                    1
# 18                      Kỹ thuật điện tử - viễn thông                    1
# 19                 Kỹ thuật điều khiển và tự động hóa                    1
# 20                                Kỹ thuật cơ điện tử                    1
# 21                                  Kỹ thuật xây dựng                    1
# 22                                          Kiến trúc                    1
# 23                               Thiết kế công nghiệp                    1
# 24                                    Thiết kế đồ họa                    1
# 25                                Thiết kế thời trang                    1
# 26                                  Thiết kế nội thất                    1
# 27  Quan hệ lao động (Chuyên ngành Quản lý quan hệ...                    1
# 28  Quản lý thể dục thể thao (Chuyên ngành kinh do...                    1
# 29                                               Golf                    1
# 30                                         Xã hội học                    1
# 31                                    Công tác xã hội                    1
# 32                                    Bảo hộ lao động                    1
# 33  Công nghệ kỹ thuật môi trường (Chuyên ngành cấ...                    1
# 34                                Khoa học môi trường                    1
# 35                                      Toán ứng dụng                    1
# 36                                           Thống kê                    1
# 37                           Quy hoạch vùng và đô thị                    1
# 38            Kỹ thuật xây dựng công trình giao thông                    1
# 39                      Ngôn ngữ Anh - Chất lượng cao                    1
# 40  Việt Nam học (Chuyên ngành: Du lịch và Quản lý...                    1
# 41  Quản trị kinh doanh (Chuyên ngành: Quản trị ng...                    1
# 42                         Marketing - Chất lượng cao                    1
# 43  Quản trị kinh doanh (Chuyên ngành: Quản trị nh...                    1
# 44                Kinh doanh quốc tế - Chất lượng cao                    1
# 45             Tài chính - Ngân hàng - Chất lượng cao                    1
# 46                           Kế toán - Chất lượng cao                    1
# 47                              Luật - Chất lượng cao                    1
# 48                Công nghệ sinh học - Chất lượng cao                    1
# 49                 Khoa học máy tính - Chất lượng cao                    1
# 50                 Kỹ thuật phần mềm - Chất lượng cao                    1
# 51                     Kỹ thuật điện - Chất lượng cao                    1
# 52     Kỹ thuật điện tử - viễn thông - Chất lượng cao                    1
# 53  Kỹ thuật điều khiển và tự động hóa - Chất lượn...                    1
# 54                 Kỹ thuật xây dựng - Chất lượng cao                    1
# 55                   Thiết kế đồ họa - Chất lượng cao                    1
#
#     year subject_combination  score  \
# 0   2021            D01; D11  35,60
# 1   2021  A01; C00; C01; D01  33,30
# 2   2021  A01; C00; C01; D01  34,20
# 3   2021       A00; A01; D01  36,00
# 4   2021       A00; A01; D01  36,90
# 5   2021       A00; A01; D01  35,10
# 6   2021       A00; A01; D01  36,30
# 7   2021  A00; A01; D01; D07  34,80
# 8   2021  A00; A01; C01; D01  34,80
# 9   2021  A00; A01; C00; D01  35,00
# 10  2021       A00; B00; D07  33,80
# 11  2021  D01; D04; D11; D55  34,90
# 12  2021       A00; B00; D08  29,60
# 13  2021       A00; B00; D07  32,00
# 14  2021       A00; A01; D01  34,60
# 15  2021       A00; A01; D01  33,40
# 16  2021       A00; A01; D01  35,20
# 17  2021       A00; A01; C01  29,70
# 18  2021       A00; A01; C01  31,00
# 19  2021       A00; A01; C01  33,00
# 20  2021       A00; A01; C01  32,00
# 21  2021       A00; A01; C01  29,40
# 22  2021            V00; V01  28,00
# 23  2021       H00; H01; H02  30,50
# 24  2021       H00; H01; H02  34,00
# 25  2021       H00; H01; H02  30,50
# 26  2021       V00; V01; H02  29,00
# 27  2021  A00; A01; C01; D01  32,50
# 28  2021  A01; D01; T00; T01  32,80
# 29  2021  A01; D01; T00; T01  23,00
# 30  2021  A01; C00; C01; D01  32,90
# 31  2021  A01; C00; C01; D01  29,50
# 32  2021  A00; B00; D07; D08  23,00
# 33  2021  A00; B00; D07; D08  23,00
# 34  2021  A00; B00; D07; D08  23,00
# 35  2021            A00; A01  29,50
# 36  2021            A00; A01  28,50
# 37  2021  A00; A01; V00; V01  24,00
# 38  2021       A00; A01; C01  24,00
# 39  2021            D01; D11  34,80
# 40  2021  A01; C00; C01; D01  30,80
# 41  2021       A00; A01; D01  35,30
# 42  2021       A00; A01; D01  35,60
# 43  2021       A00; A01; D01  34,30
# 44  2021       A00; A01; D01  35,90
# 45  2021  A00; A01; D01; D07  33,70
# 46  2021  A00; A01; C01; D01  32,80
# 47  2021  A00; A01; C00; D01  33,30
# 48  2021       A00; B00; D08  24,00
# 49  2021       A00; A01; D01  33,90
# 50  2021       A00; A01; D01  34,00
# 51  2021       A00; A01; C01  24,00
# 52  2021       A00; A01; C01  24,00
# 53  2021       A00; A01; C01  28,00
# 54  2021       A00; A01; C01  24,00
# 55  2021       H00; H01; H02  30,50
#
#                                                  note
# 0   Môn nhân hệ số 2, điều kiện: Anh\n Điểm trúng ...
# 1   Môn nhân hệ số 2, điều kiện: A01, D01: Anh C00...
# 2   Môn nhân hệ số 2, điều kiện: A01, D01: Anh C00...
# 3   Môn nhân hệ số 2, điều kiện: A00: Toán, A01, D...
# 4   Môn nhân hệ số 2, điều kiện: A00: Toán, A01, D...
# 5   Môn nhân hệ số 2, điều kiện: A00: Toán, A01, D...
# 6   Môn nhân hệ số 2, điều kiện: A00: Toán, A01, D...
# 7   Môn nhân hệ số 2, điều kiện: A00: Toán, A01, D...
# 8   Môn nhân hệ số 2, điều kiện: A00, C01: Toán, A...
# 9   Môn nhân hệ số 2, điều kiện: A00, A01: Toán, C...
# 10  Môn nhân hệ số 2, điều kiện: Hóa\n Điểm trúng ...
# 11  Môn nhân hệ số 2, điều kiện: D01, D11: Anh, D0...
# 12  Môn nhân hệ số 2, điều kiện: A00: Hóa, B00, D0...
# 13  Môn nhân hệ số 2, điều kiện: Hóa\n Điểm trúng ...
# 14  Môn nhân hệ số 2, điều kiện: Toán\n Điểm trúng...
# 15  Môn nhân hệ số 2, điều kiện: Toán\n Điểm trúng...
# 16  Môn nhân hệ số 2, điều kiện: Toán\n Điểm trúng...
# 17  Môn nhân hệ số 2, điều kiện: Toán\n Điểm trúng...
# 18  Môn nhân hệ số 2, điều kiện: Toán\n Điểm trúng...
# 19  Môn nhân hệ số 2, điều kiện: Toán\n Điểm trúng...
# 20  Môn nhân hệ số 2, điều kiện: Toán\n Điểm trúng...
# 21  Môn nhân hệ số 2, điều kiện: Toán\n Điểm trúng...
# 22  Môn nhân hệ số 2, điều kiện: Vẽ HHMT (Vẽ HHMT ...
# 23  Môn nhân hệ số 2, điều kiện: Vẽ HHMT (H00, H02...
# 24  Môn nhân hệ số 2, điều kiện: Vẽ HHMT (H00, H02...
# 25  Môn nhân hệ số 2, điều kiện: Vẽ HHMT (H00, H02...
# 26  Môn nhân hệ số 2, điều kiện: Vẽ HHMT (V00, V01...
# 27  Môn nhân hệ số 2, điều kiện: A00, C01: Toán, A...
# 28  Môn nhân hệ số 2, điều kiện: A01, D01: Anh, T0...
# 29  Môn nhân hệ số 2, điều kiện: A01, D01: Anh, T0...
# 30  Môn nhân hệ số 2, điều kiện: A01, D01: Anh, C0...
# 31  Môn nhân hệ số 2, điều kiện: A01, D01: Anh, C0...
# 32  Môn nhân hệ số 2, điều kiện: Toán\n Điểm trúng...
# 33  Môn nhân hệ số 2, điều kiện: Toán\n Điểm trúng...
# 34  Môn nhân hệ số 2, điều kiện: Toán\n Điểm trúng...
# 35  Môn nhân hệ số 2, điều kiện: Toán (Toán ≥ 5,0)...
# 36  Môn nhân hệ số 2, điều kiện: Toán (Toán ≥ 5,0)...
# 37  Môn nhân hệ số 2, điều kiện: A00, A01: Toán  <...
# 38  Môn nhân hệ số 2, điều kiện: Toán\n Điểm trúng...
# 39  Môn nhân hệ số 2, điều kiện: Anh\n Điểm trúng ...
# 40  Môn nhân hệ số 2, điều kiện: A01, D01: Anh  <b...
# 41  Môn nhân hệ số 2, điều kiện: A00:  Toán  <br>A...
# 42  Môn nhân hệ số 2, điều kiện: A00:  Toán  <br>A...
# 43  Môn nhân hệ số 2, điều kiện: A00:  Toán  <br>A...
# 44  Môn nhân hệ số 2, điều kiện: A00:  Toán  <br>A...
# 45  Môn nhân hệ số 2, điều kiện: A00: Toán  <br>A0...
# 46  Môn nhân hệ số 2, điều kiện: A00, C01: Toán  <...
# 47  Môn nhân hệ số 2, điều kiện: A00, A01: Toán  <...
# 48  Môn nhân hệ số 2, điều kiện: A00: Hóa  <br>B00...
# 49  Môn nhân hệ số 2, điều kiện: Toán\n Điểm trúng...
# 50  Môn nhân hệ số 2, điều kiện: Toán\n Điểm trúng...
# 51  Môn nhân hệ số 2, điều kiện: Toán\n Điểm trúng...
# 52  Môn nhân hệ số 2, điều kiện: Toán\n Điểm trúng...
# 53  Môn nhân hệ số 2, điều kiện: Toán\n Điểm trúng...
# 54  Môn nhân hệ số 2, điều kiện: Toán\n Điểm trúng...
# 55  Môn nhân hệ số 2, điều kiện: Vẽ HHMT  <br>H00,...

# %% [markdown]
# # Data còn lại
# - array(['TDTU', 'UEH', 'FPT', 'FTU2', 'HCMUS', 'UFM', 'UIT']
# - HCMUTE, VLU, UMP, PNTU, OU, NTTU, HCMUE, BKU.

# %%
# # Kết nối tới cơ sở dữ liệu
# with sqlite3.connect('university_admissions.db') as conn:
#     cursor = conn.cursor()
    
#     # Dữ liệu cần chèn
#     data = [
#         (8, 'Điểm xét tuyển kết hợp'),
#         (9, 'Chứng chỉ quốc tế'),
#         (10, 'Đánh giá đầu vào VSAT')
#     ]
    
#     # Chèn dữ liệu vào bảng, tránh trùng lặp
#     cursor.executemany('INSERT OR IGNORE INTO admission_methods (id, name) VALUES (?, ?)', data)
    
#     # Lưu thay đổi
#     conn.commit()

# print("Data has been updated successfully.")

# %%
# Insert more method admission
read_sql_query('SELECT * FROM admission_methods  LIMIT 20;',
               "university_admissions.db")
# Out:
# (1, 'Thi THPT')
# (2, 'Học bạ - Kết quả học tập THPT đợt 1')
# (3, 'Học bạ - Kết quả học tập THPT đợt 2')
# (4, 'DGNL')
# (5, 'UTXT đợt 1')
# (6, 'UTXT đợt 2')
# (7, 'Xét riêng')
# (8, 'Điểm xét tuyển kết hợp')
# (9, 'Chứng chỉ quốc tế')
# (10, 'Đánh giá đầu vào VSAT')

# %%
read_sql_query('SELECT * FROM admission_methods  LIMIT 20;',
               "university_admissions.db")

# %%
query = f"SELECT * FROM admission_scores ;"

# Connect to the database and execute the query
with sqlite3.connect("university_admissions.db") as conn:
    df = pd.read_sql_query(query, conn)

# Display the filtered result
df["university_code"].unique()
# Out:
# array(['TDTU', 'UEH', 'FPT', 'FTU2', 'HCMUS', 'UFM', 'UIT', 'BKU',
#        'HCMUE', 'HCMUTE', 'NTTU', 'OU', 'PNTU', 'UMP', 'VLU'],
#       dtype=object)

# %%
df.shape
# Out:
# (6338, 9)

# %%
allowed_universities = {'HCMUTE', 'VLU', 'UMP', 'PNTU', 'OU', 'NTTU', 'HCMUE', 'BKU'}
insert_admission_scores_from_folders(r'E:\LLM_clone\Tdtu-chatbot\notebooks\Data Tuyển sinh', allowed_universities)

# %% [markdown]
# # View data

# %%
query = f"SELECT * FROM admission_scores ;"

# Connect to the database and execute the query
with sqlite3.connect("university_admissions.db") as conn:
    df = pd.read_sql_query(query, conn)

# Display the filtered result
df
# Out:
#         id university_code major_code  \
# 0        1            TDTU    7220201
# 1        2            TDTU    7310630
# 2        3            TDTU   7310630Q
# 3        4            TDTU    7340101
# 4        5            TDTU    7340115
# ...    ...             ...        ...
# 6333  6334             VLU    7720601
# 6334  6335             VLU    7810101
# 6335  6336             VLU    7810103
# 6336  6337             VLU    7810201
# 6337  6338             VLU    7810202
#
#                                              major_name  admission_method_id  \
# 0                                          Ngôn ngữ Anh                    1
# 1       Việt Nam học (Chuyên ngành: Du lịch và lữ hành)                    1
# 2     Việt Nam học (Chuyên ngành: Du lịch và quản lý...                    1
# 3     Quản trị kinh doanh (Chuyên ngành: Quản trị ng...                    1
# 4                                             Marketing                    1
# ...                                                 ...                  ...
# 6333                          Kỹ thuật Xét nghiệm Y học                    4
# 6334                                            Du lịch                    4
# 6335                 Quản trị Dịch vụ Du lịch & Lữ hành                    4
# 6336                                 Quản trị Khách sạn                    4
# 6337               Quản trị Nhà hàng và Dịch vụ Ăn uống                    4
#
#       year subject_combination  score  \
# 0     2021            D01; D11  35,60
# 1     2021  A01; C00; C01; D01  33,30
# 2     2021  A01; C00; C01; D01  34,20
# 3     2021       A00; A01; D01  36,00
# 4     2021       A00; A01; D01  36,90
# ...    ...                 ...    ...
# 6333  2024                None  700.0
# 6334  2024                None  650.0
# 6335  2024                None  650.0
# 6336  2024                None  650.0
# 6337  2024                None  650.0
#
#                                                    note
# 0     Môn nhân hệ số 2, điều kiện: Anh\n Điểm trúng ...
# 1     Môn nhân hệ số 2, điều kiện: A01, D01: Anh C00...
# 2     Môn nhân hệ số 2, điều kiện: A01, D01: Anh C00...
# 3     Môn nhân hệ số 2, điều kiện: A00: Toán, A01, D...
# 4     Môn nhân hệ số 2, điều kiện: A00: Toán, A01, D...
# ...                                                 ...
# 6333                Học lực lớp 12 đạt loại khá trở lên
# 6334                                               None
# 6335                                               None
# 6336                                               None
# 6337                                               None
#
# [6338 rows x 9 columns]

# %%
filename = "admission_scores.xlsx"
df.to_excel(filename, index=False)
